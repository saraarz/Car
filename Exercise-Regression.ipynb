# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.simplefilter(action = 'ignore')
plt.style.use('seaborn')

# %%
Data = pd.read_csv('D:/D/ماشین لرنینگ/cardata.csv')
Data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
Data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0
# 7      Dealer       Manual      0
# 8      Dealer       Manual      0
# 9      Dealer       Manual      0

# %%
Data.shape
# Out:
# (301, 9)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
Data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
Data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# PreProcessing

# %%
Data['Year']
# Out:
# 0      2014
# 1      2013
# 2      2017
# 3      2011
# 4      2014
#        ...
# 296    2016
# 297    2015
# 298    2009
# 299    2017
# 300    2016
# Name: Year, Length: 301, dtype: int64

# %%
np.max(Data['Year'])
# Out:
# 2018

# %%
Data['Age'] = 2019 - Data['Year']
Data.drop('Year', axis = 1, inplace = True)
Data
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0    5
# 1         Manual      0    6
# 2         Manual      0    2
# 3         Manual      0    8
# 4         Manual      0    5
# ..           ...    ...  ...
# 296       Manual      0    3
# 297       Manual      0    4
# 298       Manual      0   10
# 299       Manual      0    2
# 300       Manual      0    3
#
# [301 rows x 9 columns]

# %%
# Types of Columns
# 1) Categorical

# %%
Categorical = ['Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

i = 0
while i < 4:
    fig = plt.figure(figsize = (10, 4))
    plt.subplot(1,2,1)
    sns.countplot(x = Categorical[i], data = Data)
    i+=1
    plt.subplot(1,2,2)
    sns.countplot(x = Categorical[i], data = Data)
    i+=1
    plt.show()

# %%
# 2) Numerical (continous)

# %%
num = ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Age']

i = 0
while i<4:
    fig = plt.figure(figsize = (10, 4))
    plt.subplot(1,2,1)
    sns.boxplot(x = num[i], data = Data)
    i+=1
    plt.subplot(1,2,2)
    sns.boxplot(x = num[i], data = Data)
    i+=1
    plt.show()

# %%
Data.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       Age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# Age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
print(pd.unique(Data["Fuel_Type"]))
print(pd.unique(Data["Seller_Type"]))
print(pd.unique(Data["Transmission"]))
print(pd.unique(Data["Owner"]))
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
# Replace

# %%
Data["Fuel_Type"].replace({"Petrol":2, "Diesel":3, "CNG":4}, inplace = True)
Data["Seller_Type"].replace({"Dealer":2, "Individual":3}, inplace =True)
Data["Transmission"].replace({"Manual":2, "Automatic":3}, inplace=True)
Data
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz           3.35           5.59       27000          2
# 1        sx4           4.75           9.54       43000          3
# 2       ciaz           7.25           9.85        6900          2
# 3    wagon r           2.85           4.15        5200          2
# 4      swift           4.60           6.87       42450          3
# ..       ...            ...            ...         ...        ...
# 296     city           9.50          11.60       33988          3
# 297     brio           4.00           5.90       60000          2
# 298     city           3.35          11.00       87934          2
# 299     city          11.50          12.50        9000          3
# 300     brio           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner  Age
# 0              2             2      0    5
# 1              2             2      0    6
# 2              2             2      0    2
# 3              2             2      0    8
# 4              2             2      0    5
# ..           ...           ...    ...  ...
# 296            2             2      0    3
# 297            2             2      0    4
# 298            2             2      0   10
# 299            2             2      0    2
# 300            2             2      0    3
#
# [301 rows x 9 columns]

# %%
Data.drop(labels='Car_Name',axis=1,inplace=True)
Data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 296             2      0    3
# 297             2      0    4
# 298             2      0   10
# 299             2      0    2
# 300             2      0    3
#
# [301 rows x 8 columns]

# %%
#Creat Model

# %%
x = Data.drop('Selling_Price', axis = 1)
y = Data['Selling_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
print("x train :", x_train.shape)
print("x test :", x_test.shape)
print("y train :", y_train.shape)
print("y test :", y_test.shape)
# Out:
# x train : (240, 7)
# x test : (61, 7)
# y train : (240,)
# y test : (61,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print('mean absolute error: ', metrics.mean_absolute_error(y_test, y_pred))
print('mean squared error: ', metrics.mean_squared_error(y_test, y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2 score: ', metrics.r2_score(y_test, y_pred))
# Out:
# mean absolute error:  1.0000326012144765
# mean squared error:  2.188556445657223
# root mean squared error:  1.479377046481803
# r2 score:  0.9134181721224691

# %%
# Improve Model

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing

# %%
k_fold = KFold(10)
print(cross_val_score(model, x, y.ravel(), cv=k_fold, n_jobs=1))
# Out:
# [ 6.63522141e-01  8.80842763e-01  7.23708463e-01  8.63126108e-01
#  -4.36488306e+01 -1.07944231e+03 -3.50129071e-01  7.84378582e-01
#   8.27975783e-01  8.74089252e-01]

# %%
Data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 296             2      0    3
# 297             2      0    4
# 298             2      0   10
# 299             2      0    2
# 300             2      0    3
#
# [301 rows x 8 columns]

# %%
len(Data)/10
# Out:
# 30.1

# %%
Data1 = Data[Data.index < 120]
Data2 = Data[Data.index > 210]
Data3 = Data1.append(Data2)
Data3.reset_index(drop = True, inplace = True)
Data3
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 205           9.50          11.60       33988          3            2
# 206           4.00           5.90       60000          2            2
# 207           3.35          11.00       87934          2            2
# 208          11.50          12.50        9000          3            2
# 209           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 205             2      0    3
# 206             2      0    4
# 207             2      0   10
# 208             2      0    2
# 209             2      0    3
#
# [210 rows x 8 columns]

# %%
x2 = Data3.drop('Selling_Price', axis = 1)
y2 = Data3['Selling_Price']
x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size = 0.2, random_state = 0)
model2 = LinearRegression()
model2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = model2.predict(x_test2)

# %%
print("x train :", x_train2.shape)
print("x test :", x_test2.shape)
print("y train :", y_train2.shape)
print("y test :", y_test2.shape)
# Out:
# x train : (168, 7)
# x test : (42, 7)
# y train : (168,)
# y test : (42,)

# %%
print('mean absolute error: ', metrics.mean_absolute_error(y_test2, y_pred2))
print('mean squared error: ', metrics.mean_squared_error(y_test2, y_pred2))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print('r2 score: ', metrics.r2_score(y_test2, y_pred2))
# Out:
# mean absolute error:  1.7953674630296266
# mean squared error:  9.967500447635533
# root mean squared error:  3.157134847870064
# r2 score:  0.7498059627358654

# %%
print("intercept : ", model2.intercept_)
print("Coef : ",model2.coef_)
# Out:
# intercept :  1.9594852703791732
# Coef :  [ 5.59763569e-01 -3.44803303e-05  1.56038057e+00 -1.29857265e+00
#   6.79320600e-01 -9.17028504e-01 -4.32308844e-01]

# %%
y_pred2 = model2.predict([[11.23, 42000, 1, 4, 6, 1, 10]])
y_pred2
# Out:
# array([1.99935289])

# %%
# Check out noise

# %%
# Creat new Model

# %%
X = pd.DataFrame(Data, columns = ['Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'Age'])
Y = Data.Selling_Price.values.reshape(-1, 1)
Data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 296             2      0    3
# 297             2      0    4
# 298             2      0   10
# 299             2      0    2
# 300             2      0    3
#
# [301 rows x 8 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
Model = LinearRegression()
Model.fit(X_train, Y_train)
Y_pred = Model.predict(X_test)
print('mean absolute error: ', metrics.mean_absolute_error(Y_test, Y_pred))
print('mean squared error: ', metrics.mean_squared_error(Y_test, Y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('r2 score: ', metrics.r2_score(Y_test, Y_pred))
# Out:
# mean absolute error:  1.0000326012144765
# mean squared error:  2.188556445657223
# root mean squared error:  1.479377046481803
# r2 score:  0.9134181721224691

# %%
# Dimension ^ 2

# %%
def check(Dimension,testsize):
    r2 = 0.7498059627358654
    for column in X:
        new_col_name = column + str(Dimension)
        new_col_val = X[column]**Dimension
        X.insert(0, new_col_name, new_col_val)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
        new_model = LinearRegression()
        new_model.fit(X_train, Y_train)
        y_pred = new_model.predict(X_test)
        r2_new = metrics.r2_score(Y_test, Y_pred)
        if r2_new < r2:
            x.drop([new_col_name], axis=1, inplace=True)
        else:
            r2 = r2_new
    print("R2 : ",r2)

check(2,0.2)
# Out:
# R2 :  0.9134181721224691

# %%
X
# Out:
#      Age2  Owner2  Transmission2  Seller_Type2  Fuel_Type2  Kms_Driven2  \
# 0      25       0              4             4           4    729000000
# 1      36       0              4             4           9   1849000000
# 2       4       0              4             4           4     47610000
# 3      64       0              4             4           4     27040000
# 4      25       0              4             4           9   1802002500
# ..    ...     ...            ...           ...         ...          ...
# 296     9       0              4             4           9   1155184144
# 297    16       0              4             4           4   3600000000
# 298   100       0              4             4           4   7732388356
# 299     4       0              4             4           9     81000000
# 300     9       0              4             4           4     29855296
#
#      Present_Price2  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           31.2481           5.59       27000          2            2
# 1           91.0116           9.54       43000          3            2
# 2           97.0225           9.85        6900          2            2
# 3           17.2225           4.15        5200          2            2
# 4           47.1969           6.87       42450          3            2
# ..              ...            ...         ...        ...          ...
# 296        134.5600          11.60       33988          3            2
# 297         34.8100           5.90       60000          2            2
# 298        121.0000          11.00       87934          2            2
# 299        156.2500          12.50        9000          3            2
# 300         34.8100           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 296             2      0    3
# 297             2      0    4
# 298             2      0   10
# 299             2      0    2
# 300             2      0    3
#
# [301 rows x 14 columns]

# %%
# Dot Product Feature

# %%
pres_kms = X["Present_Price"]*X["Kms_Driven"]
pres_kms2 = X["Present_Price"]*X["Kms_Driven2"]
pres_fuel = X["Present_Price"]*X["Fuel_Type"]
pres_fuel2 = X["Present_Price"]*X["Fuel_Type2"]
pres2_kms = X["Present_Price2"]*X["Kms_Driven"]
pres2_kms2 = X["Present_Price2"]*X["Kms_Driven2"]
pres2_fuel = X["Present_Price2"]*X["Fuel_Type"]
pres2_fuel2 = X["Present_Price2"]*X["Fuel_Type2"]

# %%
X.insert(0, "pres_kms", pres_kms)
X.insert(0, "pres_kms2", pres_kms2)
X.insert(0, "pres_fuel", pres_fuel)
X.insert(0, "pres_fuel2", pres_fuel2)
X.insert(0, "pres2_kms", pres2_kms)
X.insert(0, "pres2_kms2", pres2_kms2)
X.insert(0, "pres2_fuel", pres2_fuel)
X.insert(0, "pres2_fuel2", pres2_fuel2)
X
# Out:
#      pres2_fuel2  pres2_fuel    pres2_kms2     pres2_kms  pres_fuel2  \
# 0       124.9924     62.4962  2.277986e+10  8.436987e+05       22.36
# 1       819.1044    273.0348  1.682804e+11  3.913499e+06       85.86
# 2       388.0900    194.0450  4.619241e+09  6.694552e+05       39.40
# 3        68.8900     34.4450  4.656964e+08  8.955700e+04       16.60
# 4       424.7721    141.5907  8.504893e+10  2.003508e+06       61.83
# ..           ...         ...           ...           ...         ...
# 296    1211.0400    403.6800  1.554416e+11  4.573425e+06      104.40
# 297     139.2400     69.6200  1.253160e+11  2.088600e+06       23.60
# 298     484.0000    242.0000  9.356190e+11  1.064001e+07       44.00
# 299    1406.2500    468.7500  1.265625e+10  1.406250e+06      112.50
# 300     139.2400     69.6200  1.039263e+09  1.902018e+05       23.60
#
#      pres_fuel     pres_kms2  pres_kms  Age2  Owner2  ...  Fuel_Type2  \
# 0        11.18  4.075110e+09  150930.0    25       0  ...           4
# 1        28.62  1.763946e+10  410220.0    36       0  ...           9
# 2        19.70  4.689585e+08   67965.0     4       0  ...           4
# 3         8.30  1.122160e+08   21580.0    64       0  ...           4
# 4        20.61  1.237976e+10  291631.5    25       0  ...           9
# ..         ...           ...       ...   ...     ...  ...         ...
# 296      34.80  1.340014e+10  394260.8     9       0  ...           9
# 297      11.80  2.124000e+10  354000.0    16       0  ...           4
# 298      22.00  8.505627e+10  967274.0   100       0  ...           4
# 299      37.50  1.012500e+09  112500.0     4       0  ...           9
# 300      11.80  1.761462e+08   32237.6     9       0  ...           4
#
#      Kms_Driven2  Present_Price2  Present_Price  Kms_Driven  Fuel_Type  \
# 0      729000000         31.2481           5.59       27000          2
# 1     1849000000         91.0116           9.54       43000          3
# 2       47610000         97.0225           9.85        6900          2
# 3       27040000         17.2225           4.15        5200          2
# 4     1802002500         47.1969           6.87       42450          3
# ..           ...             ...            ...         ...        ...
# 296   1155184144        134.5600          11.60       33988          3
# 297   3600000000         34.8100           5.90       60000          2
# 298   7732388356        121.0000          11.00       87934          2
# 299     81000000        156.2500          12.50        9000          3
# 300     29855296         34.8100           5.90        5464          2
#
#      Seller_Type  Transmission  Owner  Age
# 0              2             2      0    5
# 1              2             2      0    6
# 2              2             2      0    2
# 3              2             2      0    8
# 4              2             2      0    5
# ..           ...           ...    ...  ...
# 296            2             2      0    3
# 297            2             2      0    4
# 298            2             2      0   10
# 299            2             2      0    2
# 300            2             2      0    3
#
# [301 rows x 22 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
Model = LinearRegression()
Model.fit(X_train, Y_train)
Y_pred = Model.predict(X_test)
print('mean absolute error: ', metrics.mean_absolute_error(Y_test, Y_pred))
print('mean squared error: ', metrics.mean_squared_error(Y_test, Y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('r2 score: ', metrics.r2_score(Y_test, Y_pred))
# Out:
# mean absolute error:  0.7132283463895769
# mean squared error:  1.1387993146822435
# root mean squared error:  1.0671454046577924
# r2 score:  0.9549477801011165

# %%
############################################

# %%
k_fold = KFold(n_splits = 5) #kfold(6)
results = (cross_val_score(Model, X, Y.ravel(), cv=k_fold, n_jobs=1))
print(results)
print(np.mean(results))
# Out:
# [  0.9262662    0.57019353 -24.38089267   0.53963171   0.88913409]
# -4.291133429546342

# %%
X.shape
# Out:
# (301, 22)

# %%
301/6
# Out:
# 50.166666666666664

# %%
df = X[X.index < 100]
df2 = X[X.index > 151]
X_new = df.append(df2)
X_new.reset_index(drop = True, inplace = True)
X_new
# Out:
#      pres2_fuel2  pres2_fuel    pres2_kms2     pres2_kms  pres_fuel2  \
# 0       124.9924     62.4962  2.277986e+10  8.436987e+05       22.36
# 1       819.1044    273.0348  1.682804e+11  3.913499e+06       85.86
# 2       388.0900    194.0450  4.619241e+09  6.694552e+05       39.40
# 3        68.8900     34.4450  4.656964e+08  8.955700e+04       16.60
# 4       424.7721    141.5907  8.504893e+10  2.003508e+06       61.83
# ..           ...         ...           ...           ...         ...
# 244    1211.0400    403.6800  1.554416e+11  4.573425e+06      104.40
# 245     139.2400     69.6200  1.253160e+11  2.088600e+06       23.60
# 246     484.0000    242.0000  9.356190e+11  1.064001e+07       44.00
# 247    1406.2500    468.7500  1.265625e+10  1.406250e+06      112.50
# 248     139.2400     69.6200  1.039263e+09  1.902018e+05       23.60
#
#      pres_fuel     pres_kms2  pres_kms  Age2  Owner2  ...  Fuel_Type2  \
# 0        11.18  4.075110e+09  150930.0    25       0  ...           4
# 1        28.62  1.763946e+10  410220.0    36       0  ...           9
# 2        19.70  4.689585e+08   67965.0     4       0  ...           4
# 3         8.30  1.122160e+08   21580.0    64       0  ...           4
# 4        20.61  1.237976e+10  291631.5    25       0  ...           9
# ..         ...           ...       ...   ...     ...  ...         ...
# 244      34.80  1.340014e+10  394260.8     9       0  ...           9
# 245      11.80  2.124000e+10  354000.0    16       0  ...           4
# 246      22.00  8.505627e+10  967274.0   100       0  ...           4
# 247      37.50  1.012500e+09  112500.0     4       0  ...           9
# 248      11.80  1.761462e+08   32237.6     9       0  ...           4
#
#      Kms_Driven2  Present_Price2  Present_Price  Kms_Driven  Fuel_Type  \
# 0      729000000         31.2481           5.59       27000          2
# 1     1849000000         91.0116           9.54       43000          3
# 2       47610000         97.0225           9.85        6900          2
# 3       27040000         17.2225           4.15        5200          2
# 4     1802002500         47.1969           6.87       42450          3
# ..           ...             ...            ...         ...        ...
# 244   1155184144        134.5600          11.60       33988          3
# 245   3600000000         34.8100           5.90       60000          2
# 246   7732388356        121.0000          11.00       87934          2
# 247     81000000        156.2500          12.50        9000          3
# 248     29855296         34.8100           5.90        5464          2
#
#      Seller_Type  Transmission  Owner  Age
# 0              2             2      0    5
# 1              2             2      0    6
# 2              2             2      0    2
# 3              2             2      0    8
# 4              2             2      0    5
# ..           ...           ...    ...  ...
# 244            2             2      0    3
# 245            2             2      0    4
# 246            2             2      0   10
# 247            2             2      0    2
# 248            2             2      0    3
#
# [249 rows x 22 columns]

# %%
Y = Data['Selling_Price']
Y1 = Y[Y.index < 100]
Y2 = Y[Y.index > 151]
Y_new = Y1.append(Y2)
Y_new.reset_index(drop = True, inplace = True)
Y_new.shape
# Out:
# (249,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
Model = LinearRegression()
Model.fit(X_train, Y_train)
Y_pred = Model.predict(X_test)
print('mean absolute error: ', metrics.mean_absolute_error(Y_test, Y_pred))
print('mean squared error: ', metrics.mean_squared_error(Y_test, Y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('r2 score: ', metrics.r2_score(Y_test, Y_pred))
# Out:
# mean absolute error:  0.7132283463895769
# mean squared error:  1.1387993146822435
# root mean squared error:  1.0671454046577924
# r2 score:  0.9549477801011165

# %%
# Normalize

# %%
print(X_new[0:5])
X_new.insert(0, "Target", Y_new)
DataFrame = X_new
DataFrame
Scaler = preprocessing.StandardScaler().fit(DataFrame)
norm = Scaler.transform(DataFrame.astype(float))
print(norm[0:5])
# Out:
#    pres2_fuel2  pres2_fuel    pres2_kms2    pres2_kms  pres_fuel2  pres_fuel  \
# 0     124.9924     62.4962  2.277986e+10   843698.700       22.36      11.18
# 1     819.1044    273.0348  1.682804e+11  3913498.800       85.86      28.62
# 2     388.0900    194.0450  4.619241e+09   669455.250       39.40      19.70
# 3      68.8900     34.4450  4.656964e+08    89557.000       16.60       8.30
# 4     424.7721    141.5907  8.504893e+10  2003508.405       61.83      20.61
#
#       pres_kms2  pres_kms  Age2  Owner2  ...  Fuel_Type2  Kms_Driven2  \
# 0  4.075110e+09  150930.0    25       0  ...           4    729000000
# 1  1.763946e+10  410220.0    36       0  ...           9   1849000000
# 2  4.689585e+08   67965.0     4       0  ...           4     47610000
# 3  1.122160e+08   21580.0    64       0  ...           4     27040000
# 4  1.237976e+10  291631.5    25       0  ...           9   1802002500
#
#    Present_Price2  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0         31.2481           5.59       27000          2            2
# 1         91.0116           9.54       43000          3            2
# 2         97.0225           9.85        6900          2            2
# 3         17.2225           4.15        5200          2            2
# 4         47.1969           6.87       42450          3            2
#
#    Transmission  Owner  Age
# 0             2      0    5
# 1             2      0    6
# 2             2      0    2
# 3             2      0    8
# 4             2      0    5
#
# [5 rows x 22 columns]
# [[-0.398127   -0.19915804 -0.20857162 -0.17766421 -0.18249747 -0.41783499
#   -0.40646559 -0.32743706 -0.37839012 -0.34323054 -0.12111947 -0.43747864
#   -0.52623481 -0.55546267 -0.16267654 -0.22230105 -0.376193   -0.34786088
#   -0.5648916  -0.52623481 -0.43747864 -0.18219501 -0.21290707]
#  [-0.13156711 -0.06568925 -0.08708744 -0.13816369 -0.1138933   0.38333475
#    0.25999513 -0.14758589 -0.01231794 -0.10168161 -0.12111947 -0.43747864
#   -0.52623481  1.57895407 -0.09399154 -0.11908416  0.06588333  0.04254822
#    1.63288979 -0.52623481 -0.43747864 -0.18219501  0.12262369]
#  [ 0.34443269 -0.14856776 -0.13266583 -0.18259446 -0.18639148 -0.20284393
#   -0.08087813 -0.3752514  -0.49552221 -0.80436942 -0.12111947 -0.43747864
#   -0.52623481 -0.55546267 -0.20446339 -0.1087028   0.10057793 -0.83831231
#   -0.5648916  -0.52623481 -0.43747864 -0.18219501 -1.21949936]
#  [-0.49332696 -0.20994581 -0.22475761 -0.18372207 -0.1993511  -0.49050802
#   -0.51652333 -0.37998149 -0.56100972  0.51317023 -0.12111947 -0.43747864
#   -0.52623481 -0.55546267 -0.20572486 -0.24652451 -0.53735501 -0.87979328
#   -0.5648916  -0.52623481 -0.43747864 -0.18219501  0.79368522]
#  [-0.1601271  -0.14151427 -0.16293281 -0.1607594  -0.15657794  0.08015194
#   -0.04610294 -0.21732485 -0.17974419 -0.34323054 -0.12111947 -0.43747864
#   -0.52623481  1.57895407 -0.09687371 -0.19475605 -0.23293789  0.02912791
#    1.63288979 -0.52623481 -0.43747864 -0.18219501 -0.21290707]]

# %%
X_norm = DataFrame.drop(["Target"], axis = 1)
Y_norm = DataFrame["Target"].values.reshape(-1, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_norm, Y_norm, test_size = 0.2, random_state = 0)
Model = LinearRegression()
Model.fit(X_train, Y_train)
Y_pred = Model.predict(X_test)
print('mean absolute error: ', metrics.mean_absolute_error(Y_test, Y_pred))
print('mean squared error: ', metrics.mean_squared_error(Y_test, Y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('r2 score: ', metrics.r2_score(Y_test, Y_pred))
# Out:
# mean absolute error:  0.7096515413831328
# mean squared error:  0.9273017656387945
# root mean squared error:  0.9629650905608128
# r2 score:  0.9747713130768972

# %%
# Visuallisation

# %%
X_new.drop(["Target"], axis = 1, inplace = True)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_new, Y_new, test_size = 0.2, random_state = 0)
Model = LinearRegression()
Model.fit(X_train, Y_train)
Y_pred = Model.predict(X_test)
print('mean absolute error: ', metrics.mean_absolute_error(Y_test, Y_pred))
print('mean squared error: ', metrics.mean_squared_error(Y_test, Y_pred))
print('root mean squared error: ', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('r2 score: ', metrics.r2_score(Y_test, Y_pred))
# Out:
# mean absolute error:  0.7096515413831328
# mean squared error:  0.9273017656387945
# root mean squared error:  0.9629650905608128
# r2 score:  0.9747713130768972

# %%
X_test
# Out:
#       pres2_fuel2   pres2_fuel    pres2_kms2     pres2_kms  pres_fuel2  \
# 248    139.240000    69.620000  1.039263e+09  1.902018e+05      23.600
# 168     78.499600    39.249800  2.907088e+10  7.553232e+05      17.720
# 76     862.009600   431.004800  1.117164e+12  1.551617e+07      58.720
# 150    129.960000    64.980000  2.583735e+10  9.162180e+05      22.800
# 145      1.040400     0.520200  2.832489e+08  8.583300e+03       2.040
# 73     130.416400    65.208200  6.028498e+10  1.401976e+06      22.840
# 45     579.846400   289.923200  3.261636e+10  2.174424e+06      48.160
# 159   1968.696900   656.232300  4.145849e+11  9.523024e+06     133.110
# 218    400.000000   200.000000  4.808174e+11  6.934100e+06      40.000
# 213    302.760000   151.380000  3.401811e+10  1.604628e+06      34.800
# 96    5801.868900  1933.956300  5.421524e+11  1.869491e+07     228.510
# 201    882.090000   294.030000  2.258150e+11  4.704480e+06      89.100
# 83    1630.544400   543.514800  2.616118e+11  6.884521e+06     121.140
# 176    795.240000   265.080000  3.180960e+11  5.301600e+06      84.600
# 161    184.416400    92.208200  4.604937e+10  1.457074e+06      27.160
# 202    392.040000   196.020000  2.883645e+11  5.316258e+06      39.600
# 55     904.806400   452.403200  1.108388e+12  1.583411e+07      60.160
# 116      2.131600     1.065800  7.673760e+07  6.394800e+03       2.920
# 229    231.040000   115.520000  1.470459e+11  2.914339e+06      30.400
# 92     750.760000   375.380000  1.055756e+12  1.407675e+07      54.800
# 203    114.490000    57.245000  8.246158e+10  1.536313e+06      21.400
# 135      1.040400     0.520200  2.663424e+08  8.323200e+03       2.040
# 162    129.960000    64.980000  1.314458e+10  6.535039e+05      22.800
# 89     182.790400    91.395200  7.311616e+10  1.827904e+06      27.040
# 44      28.944400    14.472200  1.809025e+10  3.618050e+05      10.760
# 207    196.000000    98.000000  6.369465e+10  1.766646e+06      28.000
# 37      20.793600    10.396800  8.384499e+10  6.601968e+05       9.120
# 111      3.610000     1.805000  6.579225e+08  2.436750e+04       3.800
# 63   11638.094400  3879.364800  2.856506e+12  6.077672e+07     323.640
# 109      2.729104     1.364552  3.609240e+08  1.569235e+04       3.304
# 118      2.755600     1.377800  2.083922e+07  3.788950e+03       3.320
# 8      711.288900   237.096300  3.248176e+10  1.602218e+06      80.010
# 189    203.347600   101.673800  6.539506e+10  1.823316e+06      28.520
# 64   11813.516100  3937.838700  4.725406e+10  7.875677e+06     326.070
# 129      0.921600     0.460800  5.760000e+08  1.152000e+04       1.920
# 5      869.660100   289.886700  4.144453e+08  2.001185e+05      88.470
# 236   1156000000      184.960000         13.600       34000          2
# 130    900000000        0.336400          0.580       30000          2
# 74    6889000000       79.744900          8.930       83000          3
# 224    615040000      184.960000         13.600       24800          2
#
#      Seller_Type  Transmission  Owner  Age
# 248            2             2      0    3
# 168            2             2      0    2
# 76             2             2      0    6
# 150            2             2      0    4
# 145            3             2      0    9
# 73             2             2      0    8
# 45             2             3      0    5
# 159            2             2      0    4
# 218            2             2      0    8
# 213            2             2      0    2
# 96             2             3      0    3
# 201            2             2      0    5
# 83             2             2      0    4
# 176            2             2      0    7
# 161            2             2      0    8
# 202            2             2      0    6
# 55             2             3      0   10
# 116            3             2      0    6
# 229            2             2      0   13
# 92             2             2      0   14
# 203            2             2      0    7
# 135            3             2      0    6
# 162            2             2      0    2
# 89             2             2      0    5
# 44             2             2      0    7
# 207            2             2      0    5
# 37             3             2      0   16
# 111            3             2      0    9
# 63             2             3      0    4
# 109            3             2      0    5
# 118            3             2      0    7
# 8              2             2      0    3
# 189            2             2      1    4
# 64             2             3      0    2
# 129            3             2      0    3
# 5              2             2      0    1
# 22             2             3      0    8
# 125            3             3      0    3
# 12             2             3      0    4
# 173            2             2      0    8
# 242            2             2      0    5
# 226            2             2      0    3
# 107            3             3      0    2
# 156            2             2      0    2
# 75             2             2      0    4
# 178            2             2      0    6
# 236            2             2      0    4
# 130            3             2      0    6
# 74             2             2      0    5
# 224            2             2      0    4
#
# [50 rows x 22 columns]

# %%
X_test.insert(0, "y_test", Y_test)
X_test.insert(0, "y_pred", Y_pred)
X_test
# Out:
#         y_pred  y_test   pres2_fuel2   pres2_fuel    pres2_kms2     pres2_kms  \
# 248   5.122663    5.30    139.240000    69.620000  1.039263e+09  1.902018e+05
# 168   4.455395    3.50     78.499600    39.249800  2.907088e+10  7.553232e+05
# 76    5.228454    5.50    862.009600   431.004800  1.117164e+12  1.551617e+07
# 150   4.241112    4.40    129.960000    64.980000  2.583735e+10  9.162180e+05
# 145  -0.757478    0.16      1.040400     0.520200  2.832489e+08  8.583300e+03
# 73    2.614119    2.65    130.416400    65.208200  6.028498e+10  1.401976e+06
# 45    8.928865    7.50    579.846400   289.923200  3.261636e+10  2.174424e+06
# 159  10.476833   11.75   1968.696900   656.232300  4.145849e+11  9.523024e+06
# 218   3.625230    4.10    400.000000   200.000000  4.808174e+11  6.934100e+06
# 213   7.315904    6.50    302.760000   151.380000  3.401811e+10  1.604628e+06
# 96   20.495818   20.75   5801.868900  1933.956300  5.421524e+11  1.869491e+07
# 201   6.604016    7.20    882.090000   294.030000  2.258150e+11  4.704480e+06
# 83    9.990249   12.50   1630.544400   543.514800  2.616118e+11  6.884521e+06
# 176   5.111424    4.95    795.240000   265.080000  3.180960e+11  5.301600e+06
# 161   3.370260    2.90    184.416400    92.208200  4.604937e+10  1.457074e+06
# 202   4.801117    5.25    392.040000   196.020000  2.883645e+11  5.316258e+06
# 55    4.952501    3.60    904.806400   452.403200  1.108388e+12  1.583411e+07
# 116  -0.311992    0.42      2.131600     1.065800  7.673760e+07  6.394800e+03
# 229   2.606359    2.10    231.040000   115.520000  1.470459e+11  2.914339e+06
# 176   3600000000       88.360000          9.400       60000          3
# 161    998812816       46.104100          6.790       31604          2
# 202   2942194564       98.010000          9.900       54242          2
# 55    4900000000      226.201600         15.040       70000          2
# 116    144000000        0.532900          0.730       12000          2
# 229   2545807936       57.760000          7.600       50456          2
# 92    5625000000      187.690000         13.700       75000          2
# 203   2881005625       28.622500          5.350       53675          2
# 135   1024000000        0.260100          0.510       32000          2
# 162    404572996       32.490000          5.700       20114          2
# 89    1600000000       45.697600          6.760       40000          2
# 44    2500000000        7.236100          2.690       50000          2
# 207   1299890916       49.000000          7.000       36054          2
# 37   16129000000        5.198400          2.280      127000          2
# 111    729000000        0.902500          0.950       27000          2
# 63    2209000000     1293.121600         35.960       47000          3
# 109    529000000        0.682276          0.826       23000          2
# 118     30250000        0.688900          0.830        5500          2
# 8      410994529       79.032100          8.890       20273          3
# 189   1286369956       50.836900          7.130       35866          2
# 64      36000000     1312.612900         36.230        6000          3
# 129   2500000000        0.230400          0.480       50000          2
# 5        4289041       96.628900          9.830        2071          3
# 22    2500000000       64.160100          8.010       50000          2
# 125    576000000        0.324900          0.570       24000          2
# 12     225000000       98.803600          9.940       15000          2
# 173    507015289       21.160000          4.600       22517          2
# 242   1090254361       46.240000          6.800       33019          2
# 226     16000000       70.560000          8.400        4000          2
# 107     16000000        0.260100          0.510        4000          2
# 156     11799225       65.610000          8.100        3435          2
# 75    1296000000       46.240000          6.800       36000          2
# 178   2025000000       88.360000          9.400       45000          3
# 236   1156000000      184.960000         13.600       34000          2
# 130    900000000        0.336400          0.580       30000          2
# 74    6889000000       79.744900          8.930       83000          3
# 224    615040000      184.960000         13.600       24800          2
#
#      Seller_Type  Transmission  Owner  Age
# 248            2             2      0    3
# 168            2             2      0    2
# 76             2             2      0    6
# 150            2             2      0    4
# 145            3             2      0    9
# 73             2             2      0    8
# 45             2             3      0    5
# 159            2             2      0    4
# 218            2             2      0    8
# 213            2             2      0    2
# 96             2             3      0    3
# 201            2             2      0    5
# 83             2             2      0    4
# 176            2             2      0    7
# 161            2             2      0    8
# 202            2             2      0    6
# 55             2             3      0   10
# 116            3             2      0    6
# 229            2             2      0   13
# 92             2             2      0   14
# 203            2             2      0    7
# 135            3             2      0    6
# 162            2             2      0    2
# 89             2             2      0    5
# 44             2             2      0    7
# 207            2             2      0    5
# 37             3             2      0   16
# 111            3             2      0    9
# 63             2             3      0    4
# 109            3             2      0    5
# 118            3             2      0    7
# 8              2             2      0    3
# 189            2             2      1    4
# 64             2             3      0    2
# 129            3             2      0    3
# 5              2             2      0    1
# 22             2             3      0    8
# 125            3             3      0    3
# 12             2             3      0    4
# 173            2             2      0    8
# 242            2             2      0    5
# 226            2             2      0    3
# 107            3             3      0    2
# 156            2             2      0    2
# 75             2             2      0    4
# 178            2             2      0    6
# 236            2             2      0    4
# 130            3             2      0    6
# 74             2             2      0    5
# 224            2             2      0    4
#
# [50 rows x 24 columns]

# %%
new_df = X_test.sort_values(by='Present_Price')

# %%
a = new_df.Present_Price
b = new_df.y_test
c = new_df.Present_Price
d = new_df.y_pred

# %%
plt.figure(figsize = (20,10))
plt.scatter(a, b, color = 'blue', label = "real")
plt.scatter(c, d, color = 'orange', label = "prediction")
plt.legend(fontsize=60)
plt.show()

# %%
plt.figure(figsize = (20,10))
plt.scatter(a, b, color = 'blue', label = "real")
plt.plot(c, d, color = 'orange', label = "prediction")
plt.legend(fontsize=60)
plt.show()

# %%
# New Data

# %%
DataFrame.insert(0, "Target", Y_new)
DataFrame.columns
# Out:
# Index(['Target', 'pres2_fuel2', 'pres2_fuel', 'pres2_kms2', 'pres2_kms',
#        'pres_fuel2', 'pres_fuel', 'pres_kms2', 'pres_kms', 'Age2', 'Owner2',
#        'Transmission2', 'Seller_Type2', 'Fuel_Type2', 'Kms_Driven2',
#        'Present_Price2', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Age'],
#       dtype='object')

# %%
Present_Price = 11.23
Kms_Driven = 42000
Fuel_Type = 2
Seller_Type = 2
Transmission = 2
Owner = 1
Age = 10

Model_Input = pd.DataFrame({'Target':10,
                           'pres_kms':[((Present_Price)*(Kms_Driven))],
                           'pres_kms2':[((Present_Price)*(Kms_Driven**2))],
                           'pres_fuel':[((Present_Price)*(Fuel_Type))],
                           'pres_fuel2':[((Present_Price)*(Fuel_Type**2))],
                           'pres2_kms':[((Present_Price**2)*(Kms_Driven))],
                           'pres2_kms2':[((Present_Price**2)*(Kms_Driven**2))],
                           'pres2_fuel':[((Present_Price**2)*(Fuel_Type))],
                           'pres2_fuel2':[((Present_Price**2)*(Fuel_Type**2))],
                           'Owner2':[Owner**2],
                           'Fuel_Type2':[Fuel_Type**2],
                           'Kms_Driven2':[Kms_Driven**2],
                           'Present_Price2':[Present_Price**2],
                           'Present_Price':[Present_Price],
                           'Kms_Driven':[Kms_Driven],
                           'Fuel_Type':[Fuel_Type],
                           'Seller_Type':[Seller_Type],
                           'Transmission':[Transmission],
                           'Owner':[Owner],
                           'Age':[Age]})

# %%
Model_Input
# Out:
#    Target  pres_kms     pres_kms2  pres_fuel  pres_fuel2  pres2_kms  \
# 0      10  471660.0  1.980972e+10      22.46       44.92  5296741.8
#
#      pres2_kms2  pres2_fuel  pres2_fuel2  Owner2  Fuel_Type2  Kms_Driven2  \
# 0  2.224632e+11    252.2258     504.4516       1           4   1764000000
#
#    Present_Price2  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0        126.1129          11.23       42000          2            2
#
#    Transmission  Owner  Age
# 0             2      1   10

# %%
Final1 = DataFrame.append(Model_Input)

# %%
Final1
# Out:
#      Target  pres2_fuel2  pres2_fuel    pres2_kms2     pres2_kms  pres_fuel2  \
# 0      3.35     124.9924     62.4962  2.277986e+10  8.436987e+05       22.36
# 1      4.75     819.1044    273.0348  1.682804e+11  3.913499e+06       85.86
# 2      7.25     388.0900    194.0450  4.619241e+09  6.694552e+05       39.40
# 3      2.85      68.8900     34.4450  4.656964e+08  8.955700e+04       16.60
# 4      4.60     424.7721    141.5907  8.504893e+10  2.003508e+06       61.83
# ..      ...          ...         ...           ...           ...         ...
# 245    4.00     139.2400     69.6200  1.253160e+11  2.088600e+06       23.60
# 246    3.35     484.0000    242.0000  9.356190e+11  1.064001e+07       44.00
# 247   11.50    1406.2500    468.7500  1.265625e+10  1.406250e+06      112.50
# 248    5.30     139.2400     69.6200  1.039263e+09  1.902018e+05       23.60
# 0     10.00     504.4516    252.2258  2.224632e+11  5.296742e+06       44.92
#
#      pres_fuel     pres_kms2  pres_kms   Age2  ...  Fuel_Type2  Kms_Driven2  \
# 0        11.18  4.075110e+09  150930.0   25.0  ...           4    729000000
# 1        28.62  1.763946e+10  410220.0   36.0  ...           9   1849000000
# 2        19.70  4.689585e+08   67965.0    4.0  ...           4     47610000
# 3         8.30  1.122160e+08   21580.0   64.0  ...           4     27040000
# 4        20.61  1.237976e+10  291631.5   25.0  ...           9   1802002500
# ..         ...           ...       ...    ...  ...         ...          ...
# 245      11.80  2.124000e+10  354000.0   16.0  ...           4   3600000000
# 246      22.00  8.505627e+10  967274.0  100.0  ...           4   7732388356
# 247      37.50  1.012500e+09  112500.0    4.0  ...           9     81000000
# 248      11.80  1.761462e+08   32237.6    9.0  ...           4     29855296
# 0        22.46  1.980972e+10  471660.0    NaN  ...           4   1764000000
#
#      Present_Price2  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           31.2481           5.59       27000          2            2
# 1           91.0116           9.54       43000          3            2
# 2           97.0225           9.85        6900          2            2
# 3           17.2225           4.15        5200          2            2
# 4           47.1969           6.87       42450          3            2
# ..              ...            ...         ...        ...          ...
# 245         34.8100           5.90       60000          2            2
# 246        121.0000          11.00       87934          2            2
# 247        156.2500          12.50        9000          3            2
# 248         34.8100           5.90        5464          2            2
# 0          126.1129          11.23       42000          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 245             2      0    4
# 246             2      0   10
# 247             2      0    2
# 248             2      0    3
# 0               2      1   10
#
# [250 rows x 23 columns]

# %%
X = Final1.drop(["Target"], axis = 1)[:249]
Y = Final1[["Target"]][:249]
X_Final1 = Final1.drop(["Target"], axis =1)[249:]

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_Final1)

# %%
Y_pred
# Out:
# array([ 5.12266314,  4.45539451,  5.22845355,  4.24111155, -0.75747844,
#         2.61411892,  8.92886532, 10.47683263,  3.62523007,  7.31590357,
#        20.49581832,  6.60401586,  9.99024936,  5.11142375,  3.37026003,
#         4.80111747,  4.95250107, -0.31199212,  2.60635933,  3.46107877,
#         2.63886648,  0.10568354,  5.35141114,  4.2336577 ,  1.36449825,
#         4.4370392 ,  0.9981384 , -0.61699753, 22.32939613,  0.47088948,
#        -0.76483929,  7.85132713,  5.44047406, 36.4295633 ,  1.91322055,
#        10.66648244,  4.18682324,  1.87147614,  7.98739237,  2.07402438,
#         4.38556731,  7.17079055,  1.74652868,  7.48684361,  4.77103178,
#         5.99486037,  8.23420798,  0.09660017,  4.89329688,  8.93233572])
